# %% [markdown]
# # Data analytics with `pandas` and `matplotlib`

# %% [markdown]
# In this task, you are asked to analyze cryptocurrency data using the pandas and matplotlib libraries.
# The task looks like a laboratory work in which you have to fill in the missing cells and answer a series of questions.
#  - [Official pandas documentation](https://pandas.pydata.org/)
#  - [Official matplotlib documentation](https://matplotlib.org/index.html)

# %% [markdown]
# > **Reminder**
# >
# >Minimum points for crediting this work - **1 point**. If you do not score here 1 point, then you get a failure throughout the course (see slides from the introductory presentation).

# %% [markdown]
# ## 1. Data (2 points)

# %% [markdown]
# Downloading data for work:

# %%
# %%bash
# gdown 1e-Q_15W7ExExQarKqgjrtoO-LHi9oJs3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1e-Q_15W7ExExQarKqgjrtoO-LHi9oJs3
# To: /content/coins.csv
# 100%|██████████| 3.98M/3.98M [00:00<00:00, 164MB/s]

# %% [markdown]
# Let's start with the necessary preparations.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl  
import matplotlib.pyplot as plt
import ipywidgets  # Библиотека для интерактивных контролов в jupyter notebook'е

# %matplotlib inline

# %% [markdown]
# #### Load a pre-prepared dataset from *"coins.csv"* file. Create an object of type `pandas.DataFrame` named `coins` and select the date column as the index.

# %%
data = pd.read_csv('coins.csv', index_col=['date'])
coins = pd.DataFrame(data=data)

# %% [markdown]
# Let's see what happened

# %%
coins.head(4)
# Out:
#              price  txCount      txVolume  activeAddresses symbol      name  \
# date
# 2013-04-28  135.30  41702.0  6.879868e+07         117984.0    BTC   Bitcoin
# 2013-04-28    4.30   9174.0  4.431952e+07          17216.0    LTC  Litecoin
# 2013-04-29  134.44  51602.0  1.138128e+08          86925.0    BTC   Bitcoin
# 2013-04-29    4.37   9275.0  3.647810e+07          18395.0    LTC  Litecoin
#
#               open    high     low   close  volume        market
# date
# 2013-04-28  135.30  135.98  132.10  134.21     0.0  1.500520e+09
# 2013-04-28    4.30    4.40    4.18    4.35     0.0  7.377340e+07
# 2013-04-29  134.44  147.49  134.00  144.54     0.0  1.491160e+09
# 2013-04-29    4.37    4.57    4.23    4.38     0.0  7.495270e+07

# %% [markdown]
# Let's explain the values ​​stored in the columns
#  - date - measurement date
#  - name - full name of the coin
#  - symbol - abbreviated name of the coin
#  - price - average coin price per trading day in USD
#  - txCount - the number of transactions in the network of this coin
#  - txVolume - the volume of coins transferred between addresses in the network of this coin
#  - activeAddresses - the number of addresses that made transactions on this day in the network of this coin
#  - open - the price of the coin at the beginning of trading on the given day
#  - close - the price of the coin at the end of the trading day
#  - high - the highest price of this coin during the current trading day
#  - low - the lowest price of the given coin during the given trading day
#  - volume - trading volume of this coin on exchanges on a given day
#  - market - capitalization of this coin on a given day

# %% [markdown]
# Let's examine the data. Answer the following questions (insert cells with code and text below):

# %% [markdown]
# ### 1. How many different coins are there in the dataset? (0.4 points)

# %%
print(coins['name'].value_counts().size)
# Out:
# 70

# %% [markdown]
# ### 2. For what period do we have data? (0.4 points)

# %%
print("Start date:", coins.index.min(), sep=' ') 
print("End date:", coins.index.max(), sep=' ')
# Out:
# Start date: 2013-04-28
# End date: 2018-06-06

# %% [markdown]
# ### 3. Are there gaps in the data? What is the nature of these omissions, what are they most likely caused by? (0.5 points)

# %%
coins.isnull().sum()
# Out:
# price               327
# txCount            1520
# txVolume           1830
# activeAddresses    1520
# symbol                0
# name                  0
# open                  0
# high                  0
# low                   0
# close                 0
# volume                0
# market                0
# dtype: int64

# %% [markdown]
# ### 4. Which coin had the highest price and when? (0.2 points)

# %%
highest_price = coins.loc[coins['high'] == coins['high'].max(), ['name', 'high']]
print('The highest price was:', highest_price.name[0], highest_price.index[0], sep=' ')
# Out:
# The highest price was: Bitcoin 2017-12-17

# %% [markdown]
# ### 5. Which coin has the highest and lowest total capitalization? Build a pie chart with proportions. (0.5 points)

# %%
market_coins = coins.groupby('name')['market'].sum()
print("Max capitalization:", market_coins.idxmax(), sep=' ')
print("Min capitalization:", market_coins.idxmin(), sep=' ')

fig = plt.figure(
    figsize=(12, 3),
    facecolor='whitesmoke',
    dpi=250
)
plt.pie(market_coins.values, labels=market_coins.index)
plt.show()
# Out:
# Max capitalization: Bitcoin
# Min capitalization: KingN Coin

# %% [markdown]
# ## 2. Visualization (1 point)

# %% [markdown]
# The most interesting part of the analyst's job is to carefully look at correctly chosen and constructed charts.

# %% [markdown]
# **Implement a function to visualize the prices of the selected currency for the selected date range.**

# %% [markdown]
# The chart should show the start and end prices of sales. As well as the minimum and maximum price for that day.
# Label the graph and coordinate axes. Add a grid. Increase the image size.
# You can try using `matplotlib.finance.candlestick_ohlc` (`mpl_finance.candlestick_ohlc`), but you can do without it.

# %%
def plot_fancy_price_action(coins, symbol, start_date, end_date):
    table = coins.loc[(coins['symbol'] == symbol), ['open', 'close', 'high', 'low']]
    table = table.loc[start_date:end_date]
    
    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(111)
    
    ax.set_xlabel('Data', size=25)
    ax.set_ylabel('Price', size=25)
    plt.title('the price volatility in selected range', fontsize=20)
    
    ax.plot(table.index, table.open, color='red', label='Start sales price')
    ax.plot(table.index, table.close, color='yellow', label='End sales price')
    ax.plot(table.index, table.high, color='green', label='Maximum price per day')
    ax.plot(table.index, table.low, color='blue', label='Minimum price per day')

    ax.set_xticks(table.index.values[::table.shape[0] // 10])
    
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %% [markdown]
# Let's see what happened:

# %%
plot_fancy_price_action(coins=coins, symbol='VERI', start_date='2013-06-01', end_date='2019-06-30')

# %% [markdown]
# There is no data science in this task. It's just that an analyst should be able to build charts, or know ready-made tools.

# %% [markdown]
# ## 3. Pump and dump (1 point)

# %% [markdown]
# Cryptocurrency exchanges still remain a marginal place, a kind of wild west of the financial world. As a consequence, schemes thrive here regarding
# honest withdrawal of money. One of them is **pump'n'dump** (pump and dump).
#
# She looks like this. Several large players or many small ones agree to buy together an obscure coin with a low price and trading volume. This leads to an instant rise in price (pump), then inexperienced players come in the hope of making money on such growth. At this point, the organizers of the scheme will start selling everything (dump). The whole process takes from several minutes to several hours.

# %% [markdown]
# Your task is to **find the strongest pump'n'dump** of the coin in the given time period. To do this, for each day, we define the number `pnd` equal to the ratio of the maximum price of the coin on the given day to the maximum of the opening and closing prices on the same day. We need to find the day when `pnd` was maximum and the value of `pnd`.

# %%
def find_most_severe_pump_and_dump(coins, symbol, start_date, end_date):
    table = coins[coins['symbol'] == symbol][start_date:end_date]
    table = table.loc[start_date:end_date]
    max_oc_price = table[['open', 'close']].max(axis=1)
    pnd = table.high / max_oc_price
    return pnd.idxmax(), pnd.max()

# %%
find_most_severe_pump_and_dump(coins, symbol='BTC', start_date='2017-06-01', end_date='2018-06-01')
# Out:
# ('2017-11-29', 1.1428940004366206)

# %% [markdown]
# Compare these values ​​for different coins:

# %%
for coin_name in set(coins.symbol):
    result = find_most_severe_pump_and_dump(coins, symbol=coin_name, start_date='2017-06-01', end_date='2018-06-01')
    if result[1] < 2:
        print(result, f'pnd is within the normal range, most likely {coin_name} was not pumped up')
    else:
        print(result, f'pnd is within the normal range, most likely {coin_name} was not pumped up')
# Out:
# ('2017-10-01', 1.2906403940886697) pnd is within the normal range, most likely ADA was not pumped up
# ('2017-12-17', 1.726864726979804) pnd is within the normal range, most likely XVG was not pumped up
# ('2017-11-29', 1.1428940004366206) pnd is within the normal range, most likely BTC was not pumped up
# ('2018-04-25', 1.8054444587795122) pnd is within the normal range, most likely DCR was not pumped up
# ('2017-12-19', 1.1482493171095107) pnd is within the normal range, most likely ETC was not pumped up
# ('2017-11-28', 1.3587962962962963) pnd is within the normal range, most likely PIVX was not pumped up
# ('2018-03-13', 7.177933491925104) pnd is within the normal range, most likely BTM was not pumped up
# ('2017-07-06', 1.3514021619927934) pnd is within the normal range, most likely PAY was not pumped up
# ('2018-01-13', 1.4986168741355463) pnd is within the normal range, most likely WTC was not pumped up
# ('2017-11-20', 1.6728538283062646) pnd is within the normal range, most likely MTL was not pumped up
# ('2017-08-06', 1.7482936279178192) pnd is within the normal range, most likely AE was not pumped up
# ('2017-11-29', 1.3861630321910696) pnd is within the normal range, most likely SNT was not pumped up
# ('2017-06-07', 1.4424778761061947) pnd is within the normal range, most likely LSK was not pumped up
# ('2017-09-21', 2.9702777900454884) pnd is within the normal range, most likely MANA was not pumped up
# ('2017-09-28', 1.3298776561493881) pnd is within the normal range, most likely ZEC was not pumped up
# ('2017-12-17', 1.2747326203208558) pnd is within the normal range, most likely DOGE was not pumped up
# ('2017-07-18', 1.1433508255471652) pnd is within the normal range, most likely ETH was not pumped up
# ('2017-12-07', 2.586337382991436) pnd is within the normal range, most likely ICN was not pumped up
# ('2017-10-13', 1.7336683417085428) pnd is within the normal range, most likely ANT was not pumped up
# ('2017-10-22', 1.3952095808383234) pnd is within the normal range, most likely VTC was not pumped up
# ('2017-09-11', 3.720797720797721) pnd is within the normal range, most likely PPT was not pumped up
# ('2017-10-25', 1.3243755975664018) pnd is within the normal range, most likely KCS was not pumped up
# ('2018-02-07', 1.1082257158899496) pnd is within the normal range, most likely LTC was not pumped up
# ('2018-03-05', 1.4631857737419598) pnd is within the normal range, most likely ZIL was not pumped up
# ('2018-03-14', 1.5265126623868979) pnd is within the normal range, most likely LOOM was not pumped up
# ('2017-07-03', 1.3202933985330074) pnd is within the normal range, most likely EOS was not pumped up
# ('2017-09-23', 4.528409090909091) pnd is within the normal range, most likely LRC was not pumped up
# ('2017-12-30', 1.8916487255607852) pnd is within the normal range, most likely SRN was not pumped up
# ('2017-11-12', 1.783945106058206) pnd is within the normal range, most likely BCH was not pumped up
# ('2018-01-02', 1.211764705882353) pnd is within the normal range, most likely DRGN was not pumped up
# ('2018-05-11', 1.477601285025879) pnd is within the normal range, most likely REP was not pumped up
# ('2018-04-07', 1.1777531885963237) pnd is within the normal range, most likely CENNZ was not pumped up
# ('2017-06-11', 33.549253731343285) pnd is within the normal range, most likely VERI was not pumped up
# ('2017-08-05', 1.3698404867620457) pnd is within the normal range, most likely ETHOS was not pumped up
# ('2018-04-05', 1.254990051045648) pnd is within the normal range, most likely ZRX was not pumped up
# ('2017-09-19', 1.8519240136385777) pnd is within the normal range, most likely KNC was not pumped up
# ('2017-11-02', 1.3641688298886077) pnd is within the normal range, most likely POWR was not pumped up
# ('2017-12-25', 1.726167450721039) pnd is within the normal range, most likely CVC was not pumped up
# ('2017-11-12', 1.099009900990099) pnd is within the normal range, most likely USDT was not pumped up
# ('2018-02-21', 5.777033492822967) pnd is within the normal range, most likely BTG was not pumped up
# ('2017-10-08', 5.075208458226606) pnd is within the normal range, most likely RHOC was not pumped up
# ('2018-04-24', 1.1428571428571428) pnd is within the normal range, most likely CTXC was not pumped up
# ('2018-04-13', 1.6882121234525305) pnd is within the normal range, most likely GNT was not pumped up
# ('2017-11-29', 1.2031621370259378) pnd is within the normal range, most likely DASH was not pumped up
# ('2017-12-26', 1.176079734219269) pnd is within the normal range, most likely BNB was not pumped up
# ('2017-06-03', 1.2543352601156068) pnd is within the normal range, most likely WAVES was not pumped up
# ('2017-06-04', 1.2342492522991364) pnd is within the normal range, most likely BAT was not pumped up
# ('2017-07-14', 1.3312148056585635) pnd is within the normal range, most likely OMG was not pumped up
# ('2017-11-23', 1.6658378856041132) pnd is within the normal range, most likely QASH was not pumped up
# ('2017-09-29', 1.227206946454414) pnd is within the normal range, most likely SALT was not pumped up
# ('2018-01-04', 1.1358695652173911) pnd is within the normal range, most likely XEM was not pumped up
# ('2017-10-16', 1.332510511325105) pnd is within the normal range, most likely XLM was not pumped up
# ('2018-01-05', 1.2808988764044942) pnd is within the normal range, most likely ELF was not pumped up
# ('2017-09-14', 1.477106227106227) pnd is within the normal range, most likely GAS was not pumped up
# ('2017-06-07', 1.291362434422475) pnd is within the normal range, most likely MAID was not pumped up
# ('2017-09-16', 9.651010376843255) pnd is within the normal range, most likely TRX was not pumped up
# ('2017-06-29', 12.490562327959102) pnd is within the normal range, most likely FUN was not pumped up
# ('2017-12-16', 1.2538461538461536) pnd is within the normal range, most likely ICX was not pumped up
# ('2017-12-17', 1.359942799461642) pnd is within the normal range, most likely DGB was not pumped up
# ('2018-02-02', 1.4553773349994372) pnd is within the normal range, most likely POLY was not pumped up
# ('2017-06-10', 1.232142857142857) pnd is within the normal range, most likely NEO was not pumped up
# ('2017-11-17', 1.1758241758241759) pnd is within the normal range, most likely NAS was not pumped up
# ('2018-03-25', 1.653659748974773) pnd is within the normal range, most likely GNO was not pumped up
# ('2017-12-25', 1.3618677042801557) pnd is within the normal range, most likely ENG was not pumped up
# ('2017-11-24', 1.3624161073825503) pnd is within the normal range, most likely AION was not pumped up
# ('2017-12-27', 1.2713567839195978) pnd is within the normal range, most likely VEN was not pumped up

# %% [markdown]
# ## 4. ROI (1 point)

# %% [markdown]
# You need to calculate **return on investment (ROI)** in cryptocurrencies over a given period of time.
#
# Payback is defined as the ratio of *portfolio price change* to *portfolio initial price*. The portfolio price is the total value (in USD) of all coins in the portfolio.
#
# `investments` is a dictionary where the keys are the names of the coins, the values ​​are the amount of investments in this coin (in USD).

# %%
def compute_roi(coins, investments, start_date, end_date):
    price = coins[['symbol', 'price']]
    start_cost = sum(investments.values())
    
    start_day = price.loc[start_date:start_date]
    coins_count = dict()
    for coin_symbol in investments:
        x = start_day['price'][start_day['symbol'] == coin_symbol]
        coins_count[coin_symbol] = investments[coin_symbol] / x[0]
    
    end_day = price.loc[end_date:end_date]
    end_cost = 0
    for coin_symbol in investments:
        x = end_day['price'][end_day['symbol'] == coin_symbol]
        end_cost += x[0] * coins_count[coin_symbol]
    return (end_cost - start_cost) / start_cost

# %%
compute_roi(coins, investments={'BTC': 1000, 'LTC': 500}, start_date='2018-04-04', end_date='2018-06-01')
# Out:
# -0.035569133065275614

# %%
compute_roi(coins, investments={'BTC': 1000, 'LTC': 500}, start_date='2013-05-28', end_date='2018-06-06')
# Out:
# 51.28330296529592

# %% [markdown]
# ## 5. Technical analysis (1 point)

# %% [markdown]
# **Technical analysis** is a way to predict the behavior of a chart based on some auxiliary values ​​built on the original chart. One of the simplest methods of technical analysis is **[Bollinger Bands](https://en.wikipedia.org/wiki/Bollinger_Bands)**. Someone believes that the graph touching the border should be reflected from it.
#
# Borders are considered very simply:
#
# $$(MA \pm K\sigma),$$
#
# where `MA` is the `N` day moving average and $\sigma$ is the `N` day moving standard deviation.

# %% [markdown]
# Draw **price chart**, **moving average** and **Bollinger bands** with parameters `N (window) = 21`, `K (width) = 2`.
#
# The `rolling` function will help you here to calculate the mean and standard deviation over a sliding window.
#
# Don't forget to label the graph and axes, draw the legend and choose the best location for it.

# %%
def plot_bollinger_bands(coins, symbol, window, width):
    price = coins.loc[coins.symbol == symbol, ['price']]

    mean_l = price.rolling(window=window).mean() #
    std = price.rolling(window=window).std()
    bol_lower = mean_l - std * width
    bol_upper = mean_l + std * width
    
    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(111)
    
    ax.set_xlabel('Data', size=20)
    ax.set_ylabel('Price', size=20)
    plt.title('Technical analysis', fontsize=20)
    
    ax.plot(mean_l.index, mean_l, color='royalblue', label='Moving average')
    ax.plot(price.index, price, color='gold', label='Price')
    ax.plot(bol_lower.index, bol_lower, color='limegreen', label='Lower Bollinger Band')
    ax.plot(bol_upper.index, bol_upper, color='red', label='Upper Bollinger Band')
    
    ax.set_xticks(price.index.values[::price.shape[0] // 10])
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
plot_bollinger_bands(coins=coins, symbol='EOS', window=21, width=2)  # тут должен появиться график

# %% [markdown]
# **Conclude whether the Bollinger Rule was followed:**

# %% [markdown]
# **Your answer is here**

# %% [markdown]
# ## 6. Capitalization as an indicator (1 point)

# %% [markdown]
# Many people who trade cryptocurrencies like to look at [capitalization](https://academy.binance.com/en/articles/crypto-market-capitalization-explained). Let's understand why.

# %% [markdown]
# **Draw two more graphs:**
# 1. total capitalization of bitcoin (BTC), ether (ETH), eos (EOS), bitcoin cash (BCH), stellar (XLM) and litecoin (LTC)
# 2. shares of capitalizations of these coins from the total market capitalization.
#
# In this case, use the data starting from 2017-07-01.

# %%
def plot_coins_capitalizations(coins, symbols, start_date):
    fig = plt.figure(figsize=(16, 7))
    ax = fig.add_subplot(111)
    ax.set_xlabel('Data', size=20)
    ax.set_ylabel('Capitalization', size=20)
    plt.title('Total capitalization of coins', fontsize=20)
    for coin_symbol in symbols:
        current_coin_market = coins.loc[coins.symbol == coin_symbol, ['market']]
        current_coin_market = current_coin_market.loc[start_date:]
        ax.plot(current_coin_market.index, current_coin_market, label=coin_symbol)
        
    ax.set_xticks(current_coin_market.index.values[::current_coin_market.shape[0] // 10])
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()
    
    market_sum = coins.groupby(coins.index)['market'].sum()
    market_sum = market_sum.loc[start_date:]
    market_sum = pd.DataFrame(data=market_sum.values, columns=['market'], index=market_sum.index)
    
    fig = plt.figure(figsize=(16, 7))
    ax = fig.add_subplot(111)
    ax.set_xlabel('Data', size=20)
    ax.set_ylabel('Share of capitalization', size=20)
    plt.title('The share of capitalization from the total capitalization of the coin market', fontsize=20)
    for coin_symbol in symbols:
        current_coin_market = coins.loc[coins.symbol == coin_symbol, ['market']]
        current_coin_market = current_coin_market.loc[start_date:]
        current_coin_market = current_coin_market / market_sum
        ax.plot(current_coin_market.index, current_coin_market, label=coin_symbol)
        
    ax.set_xticks(market_sum.index.values[::market_sum.shape[0] // 10])
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
plot_coins_capitalizations(
    coins=coins,
    symbols=('BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC'),
    start_date='2017-07-01'
)

# %% [markdown]
# Analyze the dependence of the share of capitalization of altcoins (other coins, except for bitcoin) on the share of capitalization of bitcoin. What do you think is the reason for this dependence?

# %% [markdown]
# **Your answer is here**

# %% [markdown]
# ## 7. Coin correlations (1 point)

# %% [markdown]
# Now we need to take a closer look at the correlations of the average shares of coin capitalizations. In this case, we will look at the average smoothed over the last `window` days until the day `date` with a smoothing coefficient `alpha` for the set of coins `symbols`.
#
# Implement a function that will return a square `DataFrame` with the number of rows and columns equal to the number of coins in question and with correlation values:

# %%
def calc_coins_correlations(coins, date, symbols, window, alpha):
    # Paste your code here

# %%
correlations = calc_coins_correlations(coins, date="2018-06-06",
                                       symbols=['BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'],
                                       window=21, alpha=0.1)
# Теперь посмотрим на эти корреляции следующим образом:
correlations.style.background_gradient(cmap='coolwarm').set_precision(2)

# %% [markdown]
# It is quite interesting to take another look at 2017-12-27:

# %%
correlations = calc_coins_correlations(coins, date="2017-12-27",
                                       symbols=['BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'],
                                       window=21, alpha=0.1)
# Теперь посмотрим на эти корреляции следующим образом:
correlations.style.background_gradient(cmap='coolwarm').set_precision(2)

# %% [markdown]
# ## 8. Analysis of one strategy (2 points)

# %% [markdown]
# Let's take a dreamy example. Let's see how much profit a textbook trading strategy based on moving averages could bring us.
#
# The strategy looks like this: we build two moving averages for the price chart. With a small window (leading moving average) and with a large window (lagging moving average). **We buy when the leading average becomes larger than the lagging one and sell otherwise.**
#
# Let's look at an example:

# %%
def plot_moving_averages(coins, symbol, leading_window, lagging_window, start_date, end_date):
    coin = coins[coins['symbol'] == symbol][start_date:end_date]
    price = coin['price']
    leading_mean = price.rolling(window=leading_window).mean()
    lagging_mean = price.rolling(window=lagging_window).mean()

    fig = plt.figure(figsize=(16, 9))
    ax = fig.add_subplot(111)
    
    ax.set_title('Price action for {}'.format(symbol))
    ax.plot(leading_mean, color='green', label='MA{}'.format(leading_window))
    ax.plot(lagging_mean, color='red', label='MA{}'.format(lagging_window))
    ax.plot(price, color='blue', label='price')
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    ax.legend(loc='best')
    ax.grid(True)
    plt.show() 

plot_moving_averages(
    coins=coins, 
    symbol='BTC', 
    leading_window=21, 
    lagging_window=50, 
    start_date='2017-05-01',
    end_date='2018-08-01')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b0ba7e86f220> in <module>
#      19
#      20 plot_moving_averages(
# ---> 21     coins=coins,
#      22     symbol='BTC',
#      23     leading_window=21,
#
# NameError: name 'coins' is not defined

# %% [markdown]
# It can be seen that the moving average with a larger window reacts more slowly to price changes. It is on this idea that the trading strategy is based.
#
#
# **Implement a function** that draws two graphs. The right side will display the price and moving averages. On the left - how many times the size of investments will change when using our strategy and with ordinary investment (we bought and hold, we look at how the price of our purchased currencies grows).

# %% [markdown]
# >**Notes:**
# >- Let's use only closing prices. In this case, to find out the prices for yesterday, you should use the `shift (1)` method for `Series`.
# >- The ratio of closing prices for today and yesterday is **multiplier** for today. At the same time, let's build accumulation graphs for multipliers. Those. if we look at 3 days and on the first day multiplier = 1.5, on the second - 0.5 and on the third - 2, then the graph will look like this: (1.5, 1.5 *0.5, 1.5* 0.5 * 2).
# >- When using our new strategy, we will either buy if the leading average becomes larger than the lagging one by some `threshold` (in this case, it is better to divide the difference by the price first), or leave everything as it is. At the same time, of course, when making decisions for today, you need to look only at statistics from the past.

# %%
def plot_moving_averages_strategy(
    coins, symbol, lead_window, lag_window, threshold, start_date, end_date
):
    # Paste your code here
# Out:
#   File "<ipython-input-23-284c9f4504e4>", line 4
#     # Paste your code here
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
# Теперь на основе реализованной функции сделаем интерактивные графики и поизучаем, что получилось:
symbol_selector = ipywidgets.Dropdown(
    options=('BTC', 'ETH', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA'),
    index=0,
    value='BTC',
    layout={'width': '700px'},
    continuous_update=False
)

lead_window_slider = ipywidgets.IntSlider(
    value=21, 
    min=1, 
    max=200, 
    step=1,
    layout={'width': '700px'},
    continuous_update=False)

lag_window_slider = ipywidgets.IntSlider(
    value=50,
    min=1, 
    max=200, 
    layout={'width': '700px'},
    step=1, continuous_update=False)

threshold_slider = ipywidgets.FloatSlider(
    min=0, 
    max=0.20, 
    step=0.001, 
    value=0.025,
    layout={'width': '700px'},
    continuous_update=False)

start_date_slider = ipywidgets.SelectionSlider(
    options=pd.date_range('2013-04-28', '2018-06-06', freq='D'),
    index=0,
    value=pd.Timestamp('2017-05-01'),
    layout={'width': '700px'},
    continuous_update=False
)

end_date_slider = ipywidgets.SelectionSlider(
    options=pd.date_range('2013-04-28', '2018-06-06', freq='D'),
    index=0,
    value=pd.Timestamp('2018-01-01'),
    layout={'width': '700px'},
    continuous_update=False
)

ipywidgets.interact(
    plot_moving_averages_strategy,
    coins=ipywidgets.fixed(coins),
    symbol=symbol_selector,
    lead_window=lead_window_slider,
    lag_window=lag_window_slider,
    threshold=threshold_slider,
    start_date=start_date_slider,
    end_date=end_date_slider
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b364fb08e7aa> in <module>
#      48
#      49 ipywidgets.interact(
# ---> 50     plot_moving_averages_strategy,
#      51     coins=ipywidgets.fixed(coins),
#      52     symbol=symbol_selector,
#
# NameError: name 'plot_moving_averages_strategy' is not defined

# %% [markdown]
# Try different parameter values ​​for different coins and draw conclusions about the applicability of such a model:

# %% [markdown]
# **Your answer is here**

# %% [markdown]
# ## 9. Disclaimer

# %% [markdown]
# All examples of the strategies analyzed here are toys and are not suitable for real trading on the stock exchange. Without serious preparation, you will be eaten there with giblets.
